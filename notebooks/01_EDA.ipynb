# %%
# Import standard libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter

# %%
interactions_train = pd.read_csv('../data/raw/interactions_train.csv')
items = pd.read_csv('../data/raw/items.csv')
sample_submission = pd.read_csv('../data/raw/sample_submission.csv')

# %%
interactions_train.head()
# Out:
#       u      i             t
# 0  4456   8581  1.687541e+09
# 1   142   1964  1.679585e+09
# 2   362   3705  1.706872e+09
# 3  1809  11317  1.673533e+09
# 4  4384   1323  1.681402e+09

# %%
items.head()
# Out:
#                                                Title  \
# 0  Classification décimale universelle : édition ...
# 1  Les interactions dans l'enseignement des langu...
# 2  Histoire de vie et recherche biographique : pe...
# 3  Ce livre devrait me permettre de résoudre le c...
# 4                    Les années glorieuses : roman /
#
#                      Author  \
# 0                       NaN
# 1  Cicurel, Francine, 1947-
# 2                       NaN
# 3     Mazas, Sylvain, 1980-
# 4   Lemaitre, Pierre, 1951-
#
#                                           ISBN Valid     Publisher  \
# 0                          9782871303336; 2871303339   Ed du CEFAL
# 1                          9782278058327; 2278058320        Didier
# 2                          2343190194; 9782343190198   L'Harmattan
# 3  9782365350020; 236535002X; 9782365350488; 2365...       Vraoum!
# 4  9782702180815; 2702180817; 9782702183618; 2702...  Calmann-Lévy
#
#                                             Subjects  i
# 0  Classification décimale universelle; Indexatio...  0
# 1  didactique--langue étrangère - enseignement; d...  1
# 2  Histoires de vie en sociologie; Sciences socia...  2
# 3  Moyen-Orient; Bandes dessinées autobiographiqu...  3
# 4  France--1945-1975; Roman historique; Roman fra...  4

# %%
sample_submission.head()
# Out:
#    user_id                                     recommendation
# 0        0  3758 11248 9088 9895 5101 6074 9295 14050 1096...
# 1        1  3263 726 1589 14911 6432 10897 6484 7961 8249 ...
# 2        2  13508 9848 12244 2742 11120 2893 2461 5439 116...
# 3        3  2821 10734 6357 5934 2085 12608 12539 10551 10...
# 4        4  12425 219 11602 1487 14178 489 13888 2110 4413...

# %%
print(interactions_train['i'].isin(items['i']).mean())
# Out:
# 1.0

# %% [markdown]
# Since it returns 1.0, we know that "i" is indeed the item/book ID.
#
# Let's rename our columns for more clarity

# %%
interactions_train = interactions_train.rename(columns={
    'u': 'user_id',
    'i': 'item_id',
    't': 'timestamp'
})
items = items.rename(columns={'i': 'item_id'})

# %%
interactions_train.head()
# Out:
#    user_id  item_id     timestamp
# 0     4456     8581  1.687541e+09
# 1      142     1964  1.679585e+09
# 2      362     3705  1.706872e+09
# 3     1809    11317  1.673533e+09
# 4     4384     1323  1.681402e+09

# %% [markdown]
# # 1. Interaction_train
#
# `interactions.csv` – user–item interaction history (who borrowed what)

# %%
print('>>> Shape:\n', interactions_train.shape)
print('\n>>> Columns:\n',interactions_train.columns)
print('\n>>> dtypes:\n',interactions_train.dtypes)
print('\n>>> Describe:\n',interactions_train.describe())
print('\n>>> NaN-values:\n',interactions_train.isna().sum())
print('\n>>> Duplicates:\n',interactions_train.duplicated().sum())
# Out:
# >>> Shape:
#  (87047, 3)
#
# >>> Columns:
#  Index(['user_id', 'item_id', 'timestamp'], dtype='object')
#
# >>> dtypes:
#  user_id        int64
# item_id        int64
# timestamp    float64
# dtype: object
#
# >>> Describe:
#              user_id       item_id     timestamp
# count  87047.000000  87047.000000  8.704700e+04
# mean    3290.827898   6804.254598  1.695743e+09
# std     2266.663449   4441.228450  1.419829e+07
# min        0.000000      0.000000  1.672664e+09
# 25%     1309.000000   2843.000000  1.683051e+09
# 50%     2831.000000   6482.000000  1.695917e+09
# 75%     5162.000000  10620.000000  1.707222e+09
# max     7837.000000  15290.000000  1.728925e+09
#
# >>> NaN-values:
#  user_id      0
# item_id      0
# timestamp    0
# dtype: int64
#
# >>> Duplicates:
#  2

# %%
interactions_train.drop_duplicates(inplace=True)
print('\n>>> Duplicates:\n',interactions_train.duplicated().sum())
# Out:
# >>> Duplicates:
#  0

# %%
display(interactions_train)
# Out:
#        user_id  item_id     timestamp
# 0         4456     8581  1.687541e+09
# 1          142     1964  1.679585e+09
# 2          362     3705  1.706872e+09
# 3         1809    11317  1.673533e+09
# 4         4384     1323  1.681402e+09
# ...        ...      ...           ...
# 87042      924     8171  1.699284e+09
# 87043     1106     9009  1.699872e+09
# 87044     5207    13400  1.683627e+09
# 87045      698     5779  1.686667e+09
# 87046     3111     7988  1.681743e+09
#
# [87045 rows x 3 columns]

# %%
print('>>> Number of unique users:', len(interactions_train['user_id'].unique()))
print('>>> Number of unique items:', len(interactions_train['item_id'].unique()))
# Out:
# >>> Number of unique users: 7838
# >>> Number of unique items: 15109

# %% [markdown]
# ## User-Item Interaction

# %%
user_counts = interactions_train['user_id'].value_counts()

# Vizualize user-item distribution
plt.figure(figsize=(10, 6))
plt.hist(user_counts, bins=50)
plt.xlabel('Number of interactions per user')
plt.ylabel('Number of users')
plt.title('User-item distribution')
plt.show()

# %% [markdown]
# The data is Right-skewed shape, meaning it is sparses and we have many casual users and few power users.
#
# This is a sign we might need collaborative-filtering

# %%
print(user_counts.describe())
# Out:
# count    7838.000000
# mean       11.105512
# std        16.441830
# min         3.000000
# 25%         3.000000
# 50%         6.000000
# 75%        11.000000
# max       385.000000
# Name: count, dtype: float64

# %%
def bucketize_counts(counts):
    bins = [0, 3, 10, 30, 50, 100, 200, counts.max()]
    labels = ["1–3", "4–10", "11–30","31-50", "51-100", "101-200", '200+']
    return pd.cut(counts, bins=bins, labels=labels, include_lowest=True)

user_buckets = bucketize_counts(user_counts)
print(user_buckets.value_counts(normalize=True).sort_index() * 100)
# Out:
# count
# 1–3        31.194182
# 4–10       40.520541
# 11–30      21.446798
# 31-50       3.661648
# 51-100      2.551671
# 101-200     0.599643
# 200+        0.025517
# Name: proportion, dtype: float64

# %%
user_buckets.value_counts().plot.pie(autopct='%1.1f%%', figsize=(6,6))
plt.title("User Activity per # of interactions")
plt.ylabel("")
plt.show()

# %%
user_buckets.value_counts(normalize=True).sort_index().plot.bar()
plt.title("User Activity Distribution")
plt.xlabel("Interactions per User")
plt.ylabel("Percentage")
plt.show()

# %%
for number_of_interaction in range(1, user_counts.max()):
  percentage_of_users = (user_counts == number_of_interaction).mean()*100
  if percentage_of_users > 1:
    print(f">>> Users with only {number_of_interaction} interaction: {percentage_of_users:.2f}%")
# Out:
# >>> Users with only 3 interaction: 31.19%
# >>> Users with only 4 interaction: 9.59%
# >>> Users with only 5 interaction: 6.89%
# >>> Users with only 6 interaction: 6.12%
# >>> Users with only 7 interaction: 8.74%
# >>> Users with only 8 interaction: 3.47%
# >>> Users with only 9 interaction: 3.05%
# >>> Users with only 10 interaction: 2.65%
# >>> Users with only 11 interaction: 4.03%
# >>> Users with only 12 interaction: 1.59%
# >>> Users with only 13 interaction: 1.52%
# >>> Users with only 14 interaction: 1.40%
# >>> Users with only 15 interaction: 2.54%
# >>> Users with only 19 interaction: 1.35%
# >>> Users with only 23 interaction: 1.24%

# %% [markdown]
# Top 10 most active users:

# %%
user_counts.sort_values(ascending=False).head(10)
# Out:
# user_id
# 6869    385
# 4473    254
# 1884    200
# 732     199
# 1744    175
# 1106    165
# 262     163
# 2648    162
# 7507    157
# 3274    152
# Name: count, dtype: int64

# %% [markdown]
# **What does the data say ?**
#
# | Bucket      | Meaning             | % of Users |
# | ----------- | ------------------- | ---------- |
# | **3**     | Very low activity   | **31.19%** |
# | **4–10**    | Low–medium activity | **40.52%** |
# | **11–30**   | Medium activity     | **21.45%** |
# | **31–50**   | High activity       | **3.66%**  |
# | **51–100**  | Very high activity  | **2.55%**  |
# | **101–200** | Power users         | **0.60%**  |
# | **200+**    | Extreme power users | **0.03%**  |
#
#
# **Interpretation :**
#
# * The median is only 6 interaction per users.
# * **71.71%** of users have 10 or fewer interactions → extremely sparse user histories.
# * Only **6.84%** of users have more than 30 interactions.
# * Extreme power users exist but account for less than **0.1%**.
#
# This pattern is consistent with real-world recommender systems:
# most users interact infrequently, and a small minority interact very frequently. This also means *Collaborative Filtering* will struggle for ~72% of users as these "cold" user supply too feww interactions for user-user similarity, matrix factorization or neighborhood methods.
#
#
# **Solution** → We will rely on `items.csv` for **content-based** models.

# %% [markdown]
# ## Items

# %%
item_counts  = interactions_train['item_id'].value_counts()

# Vizualize user-item distribution
plt.figure(figsize=(10, 6))
plt.hist(item_counts , bins=50)
plt.xlabel('Number of interactions per items')
plt.ylabel('Number of users')
plt.title('Item-User distribution')
plt.show()

# %%
print(item_counts.describe())
# Out:
# count    15109.000000
# mean         5.761136
# std          9.004665
# min          1.000000
# 25%          3.000000
# 50%          4.000000
# 75%          6.000000
# max        380.000000
# Name: count, dtype: float64

# %%
item_buckets = bucketize_counts(item_counts)
print(item_buckets.value_counts(normalize=True).sort_index() * 100)
# Out:
# count
# 1–3        30.425574
# 4–10       62.399894
# 11–30       6.254550
# 31-50       0.503011
# 51-100      0.258124
# 101-200     0.125753
# 200+        0.033093
# Name: proportion, dtype: float64

# %%
item_buckets.value_counts().plot.pie(autopct='%1.1f%%', figsize=(6,6))
plt.title("Item Activity per # of interactions")
plt.ylabel("")
plt.show()

# %%
item_buckets.value_counts(normalize=True).sort_index().plot.bar()
plt.title("Item Activity Distribution")
plt.xlabel("Interactions per Item")
plt.ylabel("Percentage")
plt.show()

# %%
for number_of_interaction in range(1, 386):
  percentage_of_items = (item_counts == number_of_interaction).mean()*100
  if percentage_of_items > 1:
    print(f">>> Items with only {number_of_interaction} interaction: {percentage_of_items:.2f}%")
# Out:
# >>> Items with only 1 interaction: 4.58%
# >>> Items with only 2 interaction: 9.26%
# >>> Items with only 3 interaction: 16.59%
# >>> Items with only 4 interaction: 21.81%
# >>> Items with only 5 interaction: 16.90%
# >>> Items with only 6 interaction: 9.97%
# >>> Items with only 7 interaction: 5.70%
# >>> Items with only 8 interaction: 3.65%
# >>> Items with only 9 interaction: 2.49%
# >>> Items with only 10 interaction: 1.89%
# >>> Items with only 11 interaction: 1.29%

# %% [markdown]
# Top 10 items with unusually high counts

# %%
item_counts.sort_values(ascending=False).head(10)
# Out:
# item_id
# 11366    380
# 3055     357
# 10715    305
# 8999     257
# 611      217
# 4426     189
# 53       178
# 2820     177
# 14555    151
# 13885    151
# Name: count, dtype: int64

# %% [markdown]
# **What does the data say ?**
#
# | Bucket      | Meaning               | % of Items |
# | ----------- | --------------------- | ---------- |
# | **1–3**     | Very low popularity   | **30.43%** |
# | **4–10**    | Low–medium popularity | **62.40%** |
# | **11–30**   | Medium popularity     | **6.25%**  |
# | **31–50**   | High popularity       | **0.50%**  |
# | **51–100**  | Very high popularity  | **0.26%**  |
# | **100–200** | Extremely popular     | **0.13%**  |
# | **200+**    | Best-sellers          | **0.03%**  |
#
# **Interpretation :**
#
# * The median is only 4 interactions per item.
# * **92.83%** of items have between 1 and 10 interactions.
# * Only **6.84%** of users have more than 30 interactions.
# * Very few items very popular, only **0.16%**.
#
# While items are not as extremely sparse as users (many users have between 1 and 3 interactions), each item still has relatively few signals on average that limits how well pure collaborative methods can learn high-quality item representations for a large fraction of items.
#
#
# **Solution** → We will rely on `items.csv` for **content-based** models.

# %% [markdown]
# ## Timestamp

# %%
interactions_train['datetime'] = pd.to_datetime(interactions_train['timestamp'], unit='s')
interactions_train['year'] = interactions_train['datetime'].dt.year
interactions_train['month'] = interactions_train['datetime'].dt.month
interactions_train['day'] = interactions_train['datetime'].dt.day
interactions_train['week'] = interactions_train['datetime'].dt.isocalendar().week
interactions_train['day_of_week'] = interactions_train['datetime'].dt.dayofweek  # Monday=0
interactions_train
# Out:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 0         4456     8581  1.687541e+09 2023-06-23 17:24:46  2023      6   23
# 1          142     1964  1.679585e+09 2023-03-23 15:30:06  2023      3   23
# 2          362     3705  1.706872e+09 2024-02-02 11:00:59  2024      2    2
# 3         1809    11317  1.673533e+09 2023-01-12 14:19:22  2023      1   12
# 4         4384     1323  1.681402e+09 2023-04-13 16:09:22  2023      4   13
# ...        ...      ...           ...                 ...   ...    ...  ...
# 87042      924     8171  1.699284e+09 2023-11-06 15:15:47  2023     11    6
# 87043     1106     9009  1.699872e+09 2023-11-13 10:48:13  2023     11   13
# 87044     5207    13400  1.683627e+09 2023-05-09 10:02:52  2023      5    9
# 87045      698     5779  1.686667e+09 2023-06-13 14:37:48  2023      6   13
# 87046     3111     7988  1.681743e+09 2023-04-17 14:54:35  2023      4   17
#
#        week  day_of_week
# 0        25            4
# 1        12            3
# 2         5            4
# 3         2            3
# 4        15            3
# ...     ...          ...
# 87042    45            0
# 87043    46            0
# 87044    19            1
# 87045    24            1
# 87046    16            0
#
# [87045 rows x 9 columns]

# %%
# Basic timestamp stats
print(">>> Min timestamp:", interactions_train['timestamp'].min())
print("\n>>> Max timestamp:", interactions_train['timestamp'].max())
print("\n>>> Date Minimum:",interactions_train['datetime'].min())
print("\n>>> Date Maximum:",interactions_train['datetime'].max())
# Out:
# >>> Min timestamp: 1672663643.0
#
# >>> Max timestamp: 1728925054.0
#
# >>> Date Minimum: 2023-01-02 12:47:23
#
# >>> Date Maximum: 2024-10-14 16:57:34

# %%
# Interactions per month
monthly = interactions_train['datetime'].dt.to_period('M').value_counts().sort_index()
print("\n>>> Monthly:", monthly)
print("\n>>> Nunber of month:", len(monthly))

monthly.plot(kind='bar', figsize=(12,4))
plt.title("Interactions per month")
plt.ylabel("Count")
plt.show()
# Out:
# >>> Monthly: datetime
# 2023-01    5466
# 2023-02    5532
# 2023-03    5927
# 2023-04    4345
# 2023-05    4989
# 2023-06    5249
# 2023-07    3495
# 2023-08    3852
# 2023-09    5065
# 2023-10    4990
# 2023-11    5220
# 2023-12    4598
# 2024-01    5642
# 2024-02    5699
# 2024-03    4502
# 2024-04    3729
# 2024-05    3035
# 2024-06    2262
# 2024-07    1088
# 2024-08    1055
# 2024-09     984
# 2024-10     321
# Freq: M, Name: count, dtype: int64
#
# >>> Nunber of month: 22

# %%
daily = interactions_train['datetime'].dt.to_period('D').value_counts().sort_index()
daily.plot(figsize=(12,4), title='Daily Interaction Trends')
plt.show()

weekly = interactions_train['datetime'].dt.to_period('W').value_counts().sort_index()
weekly.plot(figsize=(12,4), title='Weekly Interaction Trends')
plt.show()

monthly = interactions_train['datetime'].dt.to_period('M').value_counts().sort_index()
monthly.plot(figsize=(12,4), title='Monthly Interaction Trends')
plt.show()

# %%
# Shows density of interactions across all dates.
plt.figure(figsize=(10,4))
interactions_train['datetime'].hist(bins=50)
plt.title('Distribution of Interactions Over Time')
plt.xlabel('Date')
plt.ylabel('Number of interactions')
plt.show()

# %% [markdown]
# ## Recency

# %%
# Computes how “old” each interaction is relative to the dataset end
latest_ts = interactions_train['timestamp'].max()
interactions_train['time_diff'] = latest_ts - interactions_train['timestamp']
interactions_train
# Out:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 0         4456     8581  1.687541e+09 2023-06-23 17:24:46  2023      6   23
# 1          142     1964  1.679585e+09 2023-03-23 15:30:06  2023      3   23
# 2          362     3705  1.706872e+09 2024-02-02 11:00:59  2024      2    2
# 3         1809    11317  1.673533e+09 2023-01-12 14:19:22  2023      1   12
# 4         4384     1323  1.681402e+09 2023-04-13 16:09:22  2023      4   13
# ...        ...      ...           ...                 ...   ...    ...  ...
# 87042      924     8171  1.699284e+09 2023-11-06 15:15:47  2023     11    6
# 87043     1106     9009  1.699872e+09 2023-11-13 10:48:13  2023     11   13
# 87044     5207    13400  1.683627e+09 2023-05-09 10:02:52  2023      5    9
# 87045      698     5779  1.686667e+09 2023-06-13 14:37:48  2023      6   13
# 87046     3111     7988  1.681743e+09 2023-04-17 14:54:35  2023      4   17
#
#        week  day_of_week   time_diff
# 0        25            4  41383968.0
# 1        12            3  49339648.0
# 2         5            4  22053395.0
# 3         2            3  55391892.0
# 4        15            3  47522892.0
# ...     ...          ...         ...
# 87042    45            0  29641307.0
# 87043    46            0  29052561.0
# 87044    19            1  45298482.0
# 87045    24            1  42257986.0
# 87046    16            0  47181779.0
#
# [87045 rows x 10 columns]

# %%
# Plot how many interactions happened X days ago.
plt.figure(figsize=(6,4))
plt.hist(interactions_train['time_diff']/86400, bins=50) # convert seconds to days
plt.xlabel('Days since interaction')
plt.ylabel('Count')
plt.title('Recency distribution of interactions')
plt.show()

# %%
#Interactions by year-month
pivot = interactions_train.pivot_table(index='year', columns='month', values='user_id', aggfunc='count')
sns.heatmap(pivot, annot=False, cmap='Blues')
plt.title("Heatmap of interactions over time")
plt.show()

# %% [markdown]
# **What does the data say ?**
#
# * **Earliest interaction:** January 2nd, 2023
# * **Latest interaction:** October 14th, 2024
# * Activity is relatively stable during all of 2023, with monthly interactions between **4,300** and **5,900**.
# * **Peak usage** was in Mars 2023, reaching 5927 interactions.
# * After March 2024, user activity declines steadily:
# from 4,502 (March) → 3,729 (April) → 3,035 (May) → 2,262 (June) → 1,088 (July) → 1,055 (August) → 984 (September) → 312 (October).
# * Interaction recency is heavily skewed toward **2023 and early 2024**, meaning **older interactions represent a significant portion of the dataset**.
# * User preferences have evlolved and more recent interactions are more representative of their current taste.
#
# The heavy skew toward older interactions means models trained on this data will learn outdated user preferences unless we explicitly account for temporal patterns.
#
# **Solution** → We will implement **timestamp-aware modeling** through *chronological train/test splits* and *recency-weighted interactions* to ensure recommendations reflect evolving user preferences rather than historical patterns.

# %% [markdown]
# ## Additional Visualizations

# %%
# Sort by user and timestamp
interactions_sorted = interactions_train.sort_values(['user_id', 'timestamp'])
print(">>> First 5 Interactions of the first 5 users")

# Preview first 5 interactions for the first 5 users
for user in interactions_sorted['user_id'].unique()[:5]:
    print(f"\n>>> User {user}:")
    display(interactions_sorted[interactions_sorted['user_id'] == user].head())
# Out:
# >>> First 5 Interactions of the first 5 users
#
# >>> User 0:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 21035        0        0  1.680191e+09 2023-03-30 15:44:30  2023      3   30
# 28842        0        1  1.680783e+09 2023-04-06 12:13:54  2023      4    6
# 3958         0        2  1.680801e+09 2023-04-06 17:15:08  2023      4    6
# 29592        0        3  1.683715e+09 2023-05-10 10:35:45  2023      5   10
# 6371         0        3  1.683715e+09 2023-05-10 10:35:50  2023      5   10
#
#        week  day_of_week   time_diff
# 21035    13            3  48733984.0
# 28842    14            3  48141820.0
# 3958     14            3  48123746.0
# 29592    19            2  45210109.0
# 6371     19            2  45210104.0
# >>> User 1:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 48868        1       29  1.676564e+09 2023-02-16 16:21:09  2023      2   16
# 33214        1       30  1.677844e+09 2023-03-03 11:48:06  2023      3    3
# 70235        1       31  1.681399e+09 2023-04-13 15:08:42  2023      4   13
# 73623        1       32  1.682006e+09 2023-04-20 15:46:35  2023      4   20
# 35131        1       33  1.683214e+09 2023-05-04 15:23:09  2023      5    4
#
#        week  day_of_week   time_diff
# 48868     7            3  52360585.0
# 33214     9            4  51080968.0
# 70235    15            3  47526532.0
# 73623    16            3  46919459.0
# 35131    18            3  45711265.0
# >>> User 2:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 26365        2       44  1.672854e+09 2023-01-04 17:38:34  2023      1    4
# 27162        2       45  1.673550e+09 2023-01-12 18:53:12  2023      1   12
# 74615        2       46  1.673550e+09 2023-01-12 18:56:46  2023      1   12
# 14209        2       47  1.673698e+09 2023-01-14 12:02:34  2023      1   14
# 49034        2       48  1.674662e+09 2023-01-25 15:45:36  2023      1   25
#
#        week  day_of_week   time_diff
# 26365     1            2  56071140.0
# 27162     2            3  55375462.0
# 74615     2            3  55375248.0
# 14209     2            5  55227300.0
# 49034     4            2  54263518.0
# >>> User 3:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 76960        3      116  1.672761e+09 2023-01-03 15:43:37  2023      1    3
# 53306        3      117  1.673270e+09 2023-01-09 13:21:08  2023      1    9
# 26823        3      117  1.673270e+09 2023-01-09 13:21:14  2023      1    9
# 29499        3      118  1.673270e+09 2023-01-09 13:21:20  2023      1    9
# 2834         3      119  1.674480e+09 2023-01-23 13:25:02  2023      1   23
#
#        week  day_of_week   time_diff
# 76960     1            1  56164437.0
# 53306     2            0  55654586.0
# 26823     2            0  55654580.0
# 29499     2            0  55654574.0
# 2834      4            0  54444752.0
# >>> User 4:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 75306        4      191  1.678982e+09 2023-03-16 15:51:01  2023      3   16
# 15237        4      192  1.679594e+09 2023-03-23 17:47:54  2023      3   23
# 63051        4      193  1.686066e+09 2023-06-06 15:35:52  2023      6    6
# 80481        4      194  1.686850e+09 2023-06-15 17:23:38  2023      6   15
# 63489        4      195  1.690561e+09 2023-07-28 16:15:56  2023      7   28
#
#        week  day_of_week   time_diff
# 75306    11            3  49943193.0
# 15237    12            3  49331380.0
# 63051    23            1  42859302.0
# 80481    24            3  42075236.0
# 63489    30            4  38364098.0

# %%
recency_freq = pd.DataFrame({
    'user_interactions': user_counts,
    'last_interaction': interactions_train.groupby('user_id')['timestamp'].max()
})

recency_freq['days_since_last'] = (interactions_train['timestamp'].max() - recency_freq['last_interaction'])/86400

recency_freq.plot(kind='scatter', x='user_interactions', y='days_since_last', figsize=(6,4),
                  title='Correlation Between User Activity and Recency')
plt.show()

corr = recency_freq['user_interactions'].corr(recency_freq['days_since_last'])

print("\n>>> Correlation:", corr)
# Out:
# >>> Correlation: -0.2078415899051218

# %% [markdown]
# Negative correlation → users who interact more tend to have more recent interactions. It is not very strong so not *all* heavy users are recent, but there is a clear tendency.
#
# There is a also single extreme outlier representing a user with ~400 interactions, whose last interaction occurred over ~400 days before the dataset stops. This individual is uncommon but probably not an error so we keep them in the dataset. Time-decay and normalization will reduce the influence of such rare cases.

# %% [markdown]
# ## Time Decay (next notebook)

# %%
# Normalize timestamps between 0 and 1
max_ts = interactions_train['timestamp'].max()
min_ts = interactions_train['timestamp'].min()
interactions_train['time_decay'] = np.exp(-0.1 * (max_ts - interactions_train['timestamp']) / (max_ts - min_ts))
interactions_train
# Out:
#        user_id  item_id     timestamp            datetime  year  month  day  \
# 0         4456     8581  1.687541e+09 2023-06-23 17:24:46  2023      6   23
# 1          142     1964  1.679585e+09 2023-03-23 15:30:06  2023      3   23
# 2          362     3705  1.706872e+09 2024-02-02 11:00:59  2024      2    2
# 3         1809    11317  1.673533e+09 2023-01-12 14:19:22  2023      1   12
# 4         4384     1323  1.681402e+09 2023-04-13 16:09:22  2023      4   13
# ...        ...      ...           ...                 ...   ...    ...  ...
# 87042      924     8171  1.699284e+09 2023-11-06 15:15:47  2023     11    6
# 87043     1106     9009  1.699872e+09 2023-11-13 10:48:13  2023     11   13
# 87044     5207    13400  1.683627e+09 2023-05-09 10:02:52  2023      5    9
# 87045      698     5779  1.686667e+09 2023-06-13 14:37:48  2023      6   13
# 87046     3111     7988  1.681743e+09 2023-04-17 14:54:35  2023      4   17
#
#        week  day_of_week   time_diff  time_decay
# 0        25            4  41383968.0    0.929084
# 1        12            3  49339648.0    0.916038
# 2         5            4  22053395.0    0.961560
# 3         2            3  55391892.0    0.906237
# 4        15            3  47522892.0    0.919001
# ...     ...          ...         ...         ...
# 87042    45            0  29641307.0    0.948679
# 87043    46            0  29052561.0    0.949672
# 87044    19            1  45298482.0    0.922642
# 87045    24            1  42257986.0    0.927641
# 87046    16            0  47181779.0    0.919558
#
# [87045 rows x 11 columns]

# %% [markdown]
# # 2. items EDA
#
# `items.csv` – metadata for each item (title, author, subjects, etc.)

# %%
items = pd.read_csv('https://raw.githubusercontent.com/halim-y/DSML_Kaggle_Competition/refs/heads/main/data/raw/items.csv')

# %% [markdown]
# Since it returns 1.0, we know that "i" is indeed the item/book ID.
#
# Let's rename our columns for more clarity

# %%
items = items.rename(columns={'i': 'item_id'})
display(items)
# Out:
#                                                    Title  \
# 0      Classification décimale universelle : édition ...
# 1      Les interactions dans l'enseignement des langu...
# 2      Histoire de vie et recherche biographique : pe...
# 3      Ce livre devrait me permettre de résoudre le c...
# 4                        Les années glorieuses : roman /
# ...                                                  ...
# 15286                             Le vagabond de Tokyo /
# 15287   God of high school : le match contre les dieux /
# 15288                                        Blue Lock /
# 15289            Red eyes sword : akame ga kill ! Zero /
# 15290  Directives de projet applicables à l'étude et ...
#
#                              Author  \
# 0                               NaN
# 1          Cicurel, Francine, 1947-
# 2                               NaN
# 3             Mazas, Sylvain, 1980-
# 4           Lemaitre, Pierre, 1951-
# ...                             ...
# 15286  Fukutani, Takashi, 1952-2000
# 15287                 Park, Yong-Je
# 15288           Kaneshiro, Muneyuki
# 15289                      Takahiro
# 15290                           NaN
#
#                                               ISBN Valid            Publisher  \
# 0                              9782871303336; 2871303339          Ed du CEFAL
# 1                              9782278058327; 2278058320               Didier
# 2                              2343190194; 9782343190198          L'Harmattan
# 3      9782365350020; 236535002X; 9782365350488; 2365...              Vraoum!
# 4      9782702180815; 2702180817; 9782702183618; 2702...         Calmann-Lévy
# ...                                                  ...                  ...
# 15286  9782353480111; 235348011X; 9782353480241; 2353...      Le Lézard noir
# 15287  9782382880203; 2382880201; 9782382880210; 2382...               Kbooks
# 15288  9782811650254; 2811650253; 9782811661274; 2811...                 Pika
# 15289  9782368522134; 2368522131; 9782368522141; 2368...             Kurokawa
# 15290                                                NaN  Commune de Lausanne
#
#                                                 Subjects  item_id
# 0      Classification décimale universelle; Indexatio...        0
# 1      didactique--langue étrangère - enseignement; d...        1
# 2      Histoires de vie en sociologie; Sciences socia...        2
# 3      Moyen-Orient; Bandes dessinées autobiographiqu...        3
# 4      France--1945-1975; Roman historique; Roman fra...        4
# ...                                                  ...      ...
# 15286                                             Mangas    15286
# 15287                                                NaN    15287
# 15288  Compétitions; Football; Entraînement (sports);...    15288
# 15289                           Bandes dessinées; Mangas    15289
# 15290  école (bâtiment) - construction - planificatio...    15290
#
# [15291 rows x 6 columns]

# %% [markdown]
# ## Explore dataset

# %%
print("Shape:",items.shape)
# Out:
# Shape: (15291, 6)

# %%
print('\n>>> Columns:\n',items.columns)
print("Columns types:\n",items.dtypes)
# Out:
# >>> Columns:
#  Index(['Title', 'Author', 'ISBN Valid', 'Publisher', 'Subjects', 'item_id'], dtype='object')
# Columns types:
#  Title         object
# Author        object
# ISBN Valid    object
# Publisher     object
# Subjects      object
# item_id        int64
# dtype: object

# %%
print('\n>>> Describe:\n',items.describe())
# Out:
# >>> Describe:
#              item_id
# count  15291.000000
# mean    7645.000000
# std     4414.275818
# min        0.000000
# 25%     3822.500000
# 50%     7645.000000
# 75%    11467.500000
# max    15290.000000

# %%
print('\n>>> Info:\n',items.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15291 entries, 0 to 15290
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Title       15291 non-null  object
#  1   Author      12638 non-null  object
#  2   ISBN Valid  14568 non-null  object
#  3   Publisher   15266 non-null  object
#  4   Subjects    13068 non-null  object
#  5   item_id     15291 non-null  int64
# dtypes: int64(1), object(5)
# memory usage: 716.9+ KB
#
# >>> Info:
#  None

# %% [markdown]
# ## Missing values and duplicates

# %%
print('\n>>> NaN-values:\n',items.isna().sum())
# Out:
# >>> NaN-values:
#  Title            0
# Author        2653
# ISBN Valid     723
# Publisher       25
# Subjects      2223
# item_id          0
# dtype: int64

# %%
#Bar plot of missing values
(items.isnull().mean() * 100).plot(kind='bar', figsize=(12, 6))
plt.ylabel('Percentage of missing values')
plt.title('Missing values by column')
plt.show()

# %%
#check duplicates
items.loc[items.duplicated()==True, :]
# Out:
# Empty DataFrame
# Columns: [Title, Author, ISBN Valid, Publisher, Subjects, item_id]
# Index: []

# %% [markdown]
# ## Explore Authors

# %%
print("Amount of different authors in dataset: ",items['Author'].value_counts().shape[0])
print("10 most represented authors:")
items['Author'].value_counts().head(10)
# Out:
# Amount of different authors in dataset:  9357
# 10 most represented authors:
# Author
# Pompéï, Christine          29
# Ernaux, Annie              21
# Pastoureau, Michel         21
# Bourdieu, Pierre           21
# Horikoshi, Kohei           17
# Lupano, Wilfrid            17
# Ohba, Tsugumi              14
# Robert, Paul, 1910-1980    14
# Sattouf, Riad              14
# Ferry, Luc                 14
# Name: count, dtype: int64

# %% [markdown]
# ## Explore Publishers

# %%
#Analyze publishers
print("Amount of different publisher in dataset: ",items['Publisher'].value_counts().shape[0])
print("10 most represented publishers:")
items['Publisher'].value_counts().head(10)
# Out:
# Amount of different publisher in dataset:  4337
# 10 most represented publishers:
# Publisher
# Gallimard              611
# Flammarion             241
# Albin Michel           228
# Dunod                  156
# Stämpfli               155
# Helbing Lichtenhahn    139
# Schulthess             137
# Seuil                  135
# Actes Sud              134
# La Découverte          133
# Name: count, dtype: int64

# %% [markdown]
# ## Explore Subjects

# %% [markdown]
# ### Length

# %%
# Compute number of words in the 'Subject' column
subject_count = items['Subjects'].astype(str).str.split().str.len()
subject_count
# Out:
# 0        13
# 1         7
# 2        10
# 3         6
# 4         7
#          ..
# 15286     1
# 15287     1
# 15288     6
# 15289     3
# 15290     8
# Name: Subjects, Length: 15291, dtype: int64

# %%
print("amount of words subjects describe:")
print(subject_count.describe())
# Out:
# amount of words subjects describe:
# count    15291.000000
# mean         7.462494
# std          8.461119
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%         10.000000
# max        214.000000
# Name: Subjects, dtype: float64

# %%
#frequency of each word count :
subject_count.value_counts().sort_index().head()
# Out:
# Subjects
# 1    2819
# 2    1516
# 3    1229
# 4    1256
# 5    1178
# Name: count, dtype: int64

# %% [markdown]
# ### Vizualize top terms and topics
#
# Top subjects in Dataset

# %%
#Get all subjects in a flat list
# Split by ';' and flatten all subjects into a single list
all_subjects = items['Subjects'].dropna().astype(str).str.split(';').sum()

# Remove leading/trailing whitespace from each subject
all_subjects = [subject.strip() for subject in all_subjects if subject.strip()]

# %%
#Count most common subjects
subject_counts = Counter(all_subjects)
subject_counts.most_common(20)  # Top 20 subjects
# Out:
# [('Bandes dessinées', 993),
#  ('Schweiz', 918),
#  ('Suisse', 446),
#  ('Guides pratiques', 351),
#  ('Grundlagenwerk', 260),
#  ('Guides touristiques et de visite', 251),
#  ('Mangas', 246),
#  ('Roman', 221),
#  ("[Manuels d'enseignement supérieur]", 206),
#  ('Textreproduktion', 204),
#  ('Ouvrages pour la jeunesse', 197),
#  ('Kommentar(Werk)', 163),
#  ('Histoire', 135),
#  ('Bundesrecht', 125),
#  ('[Études diverses]', 122),
#  ("Livres d'images", 119),
#  ('Switzerland', 117),
#  ('Récits personnels', 116),
#  ('Droit', 115),
#  ('Roman français', 112)]

# %%
# Combine all subjects as a single text with repeats for sizing
subjects_text = ' '.join(all_subjects)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(subjects_text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Subjects')
plt.show()

# %% [markdown]
# ##Explore Titles

# %% [markdown]
# ### Title Length

# %%
# Compute number of words in the 'Title' column
title_len = items['Title'].astype(str).str.split().str.len()
title_len.head()
# Out:
# 0     7
# 1    14
# 2    10
# 3    20
# 4     6
# Name: Title, dtype: int64

# %%
print("Title length describe:")
print(title_len.describe())
# Out:
# Title length describe:
# count    15291.000000
# mean         8.670394
# std          5.589867
# min          1.000000
# 25%          5.000000
# 50%          7.000000
# 75%         11.000000
# max         79.000000
# Name: Title, dtype: float64

# %%
#frequency of each word count :
title_len.value_counts().sort_index().head()
# Out:
# Title
# 1      48
# 2     792
# 3    1172
# 4    1442
# 5    1691
# Name: count, dtype: int64

# %%
#plot
import matplotlib.pyplot as plt

title_len.hist(bins=30)
plt.title('Distribution of Title Lengths')
plt.xlabel('Number of words')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Vizualize top terms and topics
# Top used words in Titles

# %%
from collections import Counter

# Get all words from titles, lowercased, split on whitespace
all_title_words = items['Title'].dropna().astype(str).str.split().sum()
all_title_words = [word.strip() for word in all_title_words if word.strip()]

# Count most frequent words
title_word_counts = Counter(all_title_words)
title_word_counts.most_common(20)  # Top 20 keywords in titles
# Out:
# [('/', 14923),
#  (':', 8859),
#  ('de', 5219),
#  ('et', 3467),
#  ('la', 3215),
#  ('des', 2108),
#  ('du', 1912),
#  ('La', 1602),
#  ('Le', 1460),
#  ('en', 1327),
#  ('les', 1322),
#  ('à', 1303),
#  ('le', 1221),
#  ('Les', 1002),
#  ('pour', 872),
#  ('roman', 825),
#  ('au', 631),
#  ('une', 556),
#  ('dans', 542),
#  ('sur', 517)]

# %%
# Combine all subjects as a single text with repeats for sizing
title_text = ' '.join(all_title_words)

wordcloud = WordCloud(width=800, height=400, background_color='white').generate(title_text)

plt.figure(figsize=(15, 7))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Most Common Titles')
plt.show()

# %% [markdown]
# ##General
#
# Top 20 :  Author, Publisher, and Subjects by frequency

# %% [markdown]
# ### By Value count

# %%
import matplotlib.pyplot as plt

# Top N value counts (e.g. top 20 authors)
top_n = 20

for col in ['Author', 'Publisher', 'Subjects']:
    plt.figure(figsize=(12, 6))
    items[col].value_counts().head(top_n).plot(kind='bar')
    plt.title(f'Top {top_n} {col} by frequency')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.xticks(rotation=45, ha='right')
    plt.show()

    # Print long-tail stats
    print(f'Unique values in {col}:', items[col].nunique())
    print(items[col].value_counts().tail(10))  # Last 10 counts, optional for tail
# Out:
# Unique values in Author: 9357
# Author
# Rosier, Pascal                  1
# Fossati, Julien                 1
# Wenner, Micheline               1
# Kianvach-Kechavarzi, Monireh    1
# Shirahama, Kamome               1
# Uoto, Osamu 1957-....           1
# Beckers, Jacqueline             1
# Gengembre, Gérard               1
# Kaku, Yuji                      1
# Hecht, Eugene                   1
# Name: count, dtype: int64
# Unique values in Publisher: 4337
# Publisher
# Xavier Barral                                 1
# GuinZegal                                     1
# Kehrer                                        1
# Le Lézard noir                               1
# Harrassowitz Verl                             1
# Suzanne Hurter                                1
# Fondation Louis Vuiton; Gallimard             1
# Ed Seli Arslan                                1
# L'Asiathèque - maison des langues du monde    1
# Editions G d'encre                            1
# Name: count, dtype: int64
# Unique values in Subjects: 11521
# Subjects
# politische Rechte; Stimmrechtsbeschwerde Ans Bundesgericht; Zugang zu einem Gericht; Schweiz                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    1
# canton--droit de vote--référendum--* droit constitutionnel--Suisse; politische Rechte; Abstimmung(politische Rechte); Stellungnahme der Behörde; Abstimmungsbotschaft; Anspruch auf unverfälschte Willenskundgabe; Auskunftspflicht; Behörde; Abstimmungskampf; Bundesrecht; kantonales Recht; Schweiz; Aargau; Bern(Kanton); Basel-Landschaft; Basel-Stadt(Kanton); Obwalden; Sankt Gallen(Kanton); Zürich(Kanton); Appenzell Ausserrhoden; Freiburg(Kanton); Glarus(Kanton); Graubünden; Jura; Luzern(Kanton); Neuenburg(Kanton); Schaffhausen(Kanton); Solothurn(Kanton); Thurgau; Tessin(Kanton); Uri; Genf(Kanton); Wallis; Zug(Kanton)    1
# Participation politique--Suisse--2000-....; Campagnes électorales--Suisse--2000-....; Sociologie électorale--Suisse--2000-....                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  1
# opinion publique                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# Habermas, Jürgen--Droit--Philosophie                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# Bundesverfassung; Revision(Rechtssetzung); Constitutions; Révision constitutionnelle; Droit constitutionnel; Schweiz; Suisse; Festschrift                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# démocratie directe--droits politiques--Suisse--[congrès]; Demokratie; direkte Demokratie; Schweiz                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               1
# système politique--Suisse                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# allgemeiner Teil des Obligationenrechts; Vertragsrecht; Gerichts- und Verwaltungspraxis; richterliche Behörde; oberstes Gericht; Bundesgericht; Contrats; Obligations (droit); Schweiz; Suisse; Entscheidsammlung; Lehrmittel; [Jurisprudence]; [Manuels d'enseignement supérieur]                                                                                                                                                                                                                                                                                                                                                              1
# Sexualité féminine; Vaginisme; Organes génitaux femelles                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        1
# Name: count, dtype: int64

# %% [markdown]
# ###  By Percentage

# %%
top_n = 20  # Number of top categories to display

for col in ['Publisher', 'Subjects', 'Author']:
    percentages = (value_counts / len(items)) * 100

    plt.figure(figsize=(12, 6))
    percentages.plot(kind='bar')
    plt.title(f'Top {top_n} {col} by % of full dataset')
    plt.ylabel('Percentage')
    plt.xlabel(col)
    plt.xticks(rotation=45, ha='right')
    plt.show()

# %% [markdown]
# # 3. sample_submission - EDA
#
# `sample_submission.csv` – example of the correct submission format

# %% [markdown]
# 1. Inspect Structure

# %%
sample_submission.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7838 entries, 0 to 7837
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   user_id         7838 non-null   int64
#  1   recommendation  7838 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 122.6+ KB

# %%
sample_submission.isna().sum()
# Out:
# user_id           0
# recommendation    0
# dtype: int64

# %% [markdown]
# 2. Explore the 'recommendation' column

# %%
# show first few values
sample_submission['recommendation'].head()
# Out:
# 0    3758 11248 9088 9895 5101 6074 9295 14050 1096...
# 1    3263 726 1589 14911 6432 10897 6484 7961 8249 ...
# 2    13508 9848 12244 2742 11120 2893 2461 5439 116...
# 3    2821 10734 6357 5934 2085 12608 12539 10551 10...
# 4    12425 219 11602 1487 14178 489 13888 2110 4413...
# Name: recommendation, dtype: object

# %%
# Example: split the first row into individual item_ids
example_list = str(sample_submission['recommendation'].iloc[0]).split()
example_list[:10]
# Out:
# ['3758',
#  '11248',
#  '9088',
#  '9895',
#  '5101',
#  '6074',
#  '9295',
#  '14050',
#  '10961',
#  '8240']

# %% [markdown]
# 3. Number of items per user

# %%
# Count number of items per user
sample_submission["num_items"] = (
    sample_submission["recommendation"].astype(str).apply(lambda x: len(x.split()))
)

sample_submission["num_items"].describe()
# Out:
# count    7838.0
# mean       10.0
# std         0.0
# min        10.0
# 25%        10.0
# 50%        10.0
# 75%        10.0
# max        10.0
# Name: num_items, dtype: float64

# %%
sample_submission["num_items"].hist(bins=30)
plt.title("Distribution of number of recommended items per user")
plt.xlabel("Number of items")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# 4. Check user coverage

# %%
train_users = set(interactions_train["user_id"].unique())
test_users = set(sample_submission["user_id"].unique())

print("Users in train:", len(train_users))
print("Users in sample_submission:", len(test_users))
print("Users in train but not in sample_submission:", len(train_users - test_users))
print("Users in sample_submission but not in train:", len(test_users - train_users))
# Out:
# Users in train: 7838
# Users in sample_submission: 7838
# Users in train but not in sample_submission: 0
# Users in sample_submission but not in train: 0
